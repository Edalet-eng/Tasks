# %% [markdown]
# Create a dataframe from a dictionary, where the value of keys are lists

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent':[
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
}, columns = ['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])

# %%
df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %% [markdown]
# Craete a dataframe by reading the titanic.csv file

# %%
df = sns.load_dataset(name = 'titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Display first 10 rows

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %% [markdown]
# Display any column you want

# %%
df['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %% [markdown]
# Display 'Sex', 'Age', 'Survived' columns

# %%
df[['sex', 'age', 'survived']].head(8)
# Out:
#       sex   age  survived
# 0    male  22.0         0
# 1  female  38.0         1
# 2  female  26.0         1
# 3  female  35.0         1
# 4    male  35.0         0
# 5    male   NaN         0
# 6    male  54.0         0
# 7    male   2.0         0

# %% [markdown]
# ----
# Remove all NaN values

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# ----
# ## !!!
# Display the Survived passengers

# %%
df.loc[df.survived == 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Display the unique passenger classes 'pclass'

# %%
df['pclass'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %% [markdown]
# ----
# ## !!!
# Display all passengers in age interval from 24 to 60

# %%
df.loc[(df.age > 24) & (df.age<60)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 867         0       1    male  31.0      0      0  50.4958        S   First
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 872         0       1    male  33.0      0      0   5.0000        S   First
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Replace the 0 and 1 in Survived column to False and True correspondingly

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df['survived'] = df['survived'].replace(0, False)
df['survived'] = df['survived'].replace(1, True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1        True       1  female  38.0      1      0  71.2833        C  First
# 3        True       1  female  35.0      1      0  53.1000        S  First
# 6       False       1    male  54.0      0      0  51.8625        S  First
# 10       True       3  female   4.0      1      1  16.7000        S  Third
# 11       True       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871      True       1  female  47.0      1      1  52.5542        S  First
# 872     False       1    male  33.0      0      0   5.0000        S  First
# 879      True       1  female  56.0      0      1  83.1583        C  First
# 887      True       1  female  19.0      0      0  30.0000        S  First
# 889      True       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ----
# ## !!!
# Remove the 'Ticket' column

# %%
df = df.drop(columns=['ticket'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df = df.drop(columns=['ticket'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %% [markdown]
# ## !!!
# Iterate over first 10 rows and display them

# %%
df.head(10).reset_index()
# Out:
#    index  survived  pclass     sex   age  sibsp  parch      fare embarked  \
# 0      1      True       1  female  38.0      1      0   71.2833        C
# 1      3      True       1  female  35.0      1      0   53.1000        S
# 2      6     False       1    male  54.0      0      0   51.8625        S
# 3     10      True       3  female   4.0      1      1   16.7000        S
# 4     11      True       1  female  58.0      0      0   26.5500        S
# 5     21      True       2    male  34.0      0      0   13.0000        S
# 6     23      True       1    male  28.0      0      0   35.5000        S
# 7     27     False       1    male  19.0      3      2  263.0000        S
# 8     52      True       1  female  49.0      1      0   76.7292        C
# 9     54     False       1    male  65.0      0      1   61.9792        C
#
#     class    who  adult_male deck  embark_town alive  alone
# 0   First  woman       False    C    Cherbourg   yes  False
# ...

# %% [markdown]
# ----
# ## !!!
# Remove all values from the dataframe where 'Age' is greater than 60

# %%
df_clean = df[df.age <= 60]
df_clean
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1        True       1  female  38.0      1      0  71.2833        C  First
# 3        True       1  female  35.0      1      0  53.1000        S  First
# 6       False       1    male  54.0      0      0  51.8625        S  First
# 10       True       3  female   4.0      1      1  16.7000        S  Third
# 11       True       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871      True       1  female  47.0      1      1  52.5542        S  First
# 872     False       1    male  33.0      0      0   5.0000        S  First
# 879      True       1  female  56.0      0      1  83.1583        C  First
# 887      True       1  female  19.0      0      0  30.0000        S  First
# 889      True       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ----
# ## !!!
# Read the csv file again. Count the amount of missing values and then replace them with zero.

# %%
df = sns.load_dataset(name = 'titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df = df.fillna(0)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df = df.fillna(0)
#       2 df.head()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5493, in DataFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    5482 @doc(NDFrame.fillna, **_shared_doc_kwargs)
#    5483 def fillna(
#    5484     self,
#    (...)
#    5491     downcast: dict | None = None,
#    5492 ) -> DataFrame | None:
# -> 5493     return super().fillna(
#    5494         value=value,
#    5495         method=method,
#    5496         axis=axis,
#    5497         inplace=inplace,
#    5498         limit=limit,
#    5499         downcast=downcast,
#    5500     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6983, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    6981         new_data = result
# ...

# %% [markdown]
# ----
# ## !!!
# Shuffle a dataframe

# %%
df.sample(5)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 421         0       3  male  21.0      0      0   7.7333        Q   Third
# 868         0       3  male   NaN      0      0   9.5000        S   Third
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 613         0       3  male   NaN      0      0   7.7500        Q   Third
# 407         1       2  male   3.0      1      1  18.7500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 421    man        True  NaN   Queenstown    no   True
# 868    man        True  NaN  Southampton    no   True
# 857    man        True    E  Southampton   yes   True
# 613    man        True  NaN   Queenstown    no   True
# 407  child       False  NaN  Southampton   yes  False

# %% [markdown]
# Find the average passenger fare

# %%
df['fare'].mean()
# Out:
# 32.204207968574636

# %% [markdown]
# Remove duplicate rows

# %%
df = df.drop_duplicates()
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Create a dataframe of employees and display the employees whose salary is greater 50,000.
#
#
#         Name        Age        Position        Salary
# 0       Aysu        23         Accountant      34,000
#
# 1       Richard     28         CTO             90,000

# %%
employees = pd.DataFrame({'name' : ['Nicat', 'Esmer', 'Xeyale', 'Edalet'],
            'age': [45, 54, 28, 84],
            'position' : ['President', 'Scientist', 'Doctor', 'Engineer'],
            'salary' : [14_000, 500_000, 45_000, 150_000]})
employees
# Out:
#      name  age   position  salary
# 0   Nicat   45  President   14000
# 1   Esmer   54  Scientist  500000
# 2  Xeyale   28     Doctor   45000
# 3  Edalet   84   Engineer  150000

# %%
employees[employees['salary'] > 50000]
# Out:
#      name  age   position  salary
# 1   Esmer   54  Scientist  500000
# 3  Edalet   84   Engineer  150000

# %% [markdown]
# ----
# ## !!!
# Add new row to the dataframe

# %% [markdown]
# Create an arbitrary dataframe with two columns a, b that contain numbers. Create the c column which equals to the multiplication of values of column a to column b.

# %%
data = pd.DataFrame({
    'a': [2, 5, 8, 3],
    'b': [10, 3, 6, 2]
})
data['c'] = data['a'] * data['b']
data
# Out:
#    a   b   c
# 0  2  10  20
# 1  5   3  15
# 2  8   6  48
# 3  3   2   6

# %% [markdown]
# You are provided with a dictionary, create a dataframe out of it and convert an index into a column.
#
#
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
#         'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
#         'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

# %%
import numpy as np
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'], 
             'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
             'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1], 
             'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

exam = pd.DataFrame(exam_data)
exam
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %% [markdown]
# Read world_alcohol.csv file

# %%
df = sns.load_dataset(name = 'world_alcohol.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df = sns.load_dataset(name = 'world_alcohol.csv')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:587, in load_dataset(name, cache, data_home, **kws)
#     585 if not os.path.exists(cache_path):
#     586     if name not in get_dataset_names():
# --> 587         raise ValueError(f"'{name}' is not one of the example datasets.")
#     588     urlretrieve(url, cache_path)
#     589 full_path = cache_path
#
# ValueError: 'world_alcohol.csv' is not one of the example datasets.

# %% [markdown]
# Insert proper columns, reset the index, remove unnecessary value

# %% [markdown]
# Remove the missing values from the dataframe

# %% [markdown]
# Remove duplicates from the dataframe

# %% [markdown]
# Find all unique bevrages from the dataset

# %% [markdown]
# Display the country that consumes the most and least alchol per person

# %% [markdown]
# Find out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset

# %% [markdown]
# Find the per person alcohol consumption of each year

# %% [markdown]
# Create a dataframe that will show the yearly per person alcohol consumption of all countries in the dataset. The dataframe must have two columns: country, yearly alcohol consumption.
